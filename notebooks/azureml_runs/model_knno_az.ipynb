# %%
## SET UP AZUREML DETAILS
# imports
from azureml.core.authentication import InteractiveLoginAuthentication
from azureml.core import Workspace, Environment, Experiment, Dataset, ScriptRunConfig

# set up workspace
config_path = '../../utils/config.json'
tenant_id = '72f988bf-86f1-41af-91ab-2d7cd011db47'  # this is outputted post `az login`
interactive_auth = InteractiveLoginAuthentication(tenant_id=tenant_id)  # create log-in object
ws = Workspace.from_config(path=config_path, auth=interactive_auth)  # link workspace

# set up environment
# - obtain environment.yml from `conda env export > environment.yml`
env_name = 'SampleEnv'
env_path = '../../utils/environment.yml'
env = Environment.from_conda_specification(name=env_name, file_path=env_path)

# set up experiment
experiment_name = 'kNNOSample'
exp = Experiment(workspace=ws, name=experiment_name)

# set up dataset
dataset_path = 'http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz'
ds = Dataset.File.from_files(dataset_path)

# set up run
src_dir = '../../src/azureml_runs'
src_name = 'azure_knno.py'
compute_name = 'WorkspaceCompute'
arguments = ['--data-path', ds.as_mount()]
src = ScriptRunConfig(source_directory=src_dir, script=src_name, compute_target=compute_name,
                      environment=env, arguments=arguments)
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.

# %%
## SUBMIT THE RUN
from azureml.widgets import RunDetails

run = exp.submit(src)  # submit it to the azureml platform
RunDetails(run).show()  # monitor the steps
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
# show the outputs
run.wait_for_completion(show_output=True)
# Out:
# RunId: kNNOSample_1620851888_69798bc0
# Web View: https://ml.azure.com/experiments/kNNOSample/runs/kNNOSample_1620851888_69798bc0?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/05/12 20:38:17 Downloading source code...
# 2021/05/12 20:38:19 Finished downloading source code
# 2021/05/12 20:38:19 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/05/12 20:38:19 Successfully set up Docker network: acb_default_network
# 2021/05/12 20:38:19 Setting up Docker configuration...
# 2021/05/12 20:38:20 Successfully set up Docker configuration
# 2021/05/12 20:38:20 Logging in to registry: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io
# 2021/05/12 20:38:21 Successfully logged into 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io
# 2021/05/12 20:38:21 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/12 20:38:21 Scanning for dependencies...
# 2021/05/12 20:38:22 Successfully scanned dependencies
# 2021/05/12 20:38:22 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1@sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
# sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# a358e5622b47: Pulling fs layer
# b68b2629181d: Pulling fs layer
# b40419bab046: Pulling fs layer
# 30e069d8e198: Pulling fs layer
# a82e4e12442c: Pulling fs layer
# 1bb969deda78: Pulling fs layer
# 85856583f10d: Pulling fs layer
# 103fa978967f: Pulling fs layer
# 30e069d8e198: Waiting
# a82e4e12442c: Waiting
# 1bb969deda78: Waiting
# 85856583f10d: Waiting
# 103fa978967f: Waiting
# b40419bab046: Verifying Checksum
# b40419bab046: Download complete
# b68b2629181d: Verifying Checksum
# b68b2629181d: Download complete
# 30e069d8e198: Verifying Checksum
# 30e069d8e198: Download complete
# a358e5622b47: Verifying Checksum
# a358e5622b47: Download complete
# 85856583f10d: Verifying Checksum
# 85856583f10d: Download complete
# 103fa978967f: Verifying Checksum
# 103fa978967f: Download complete
# 1bb969deda78: Verifying Checksum
# 1bb969deda78: Download complete
# a82e4e12442c: Verifying Checksum
# a82e4e12442c: Download complete
# a358e5622b47: Pull complete
# b68b2629181d: Pull complete
# b40419bab046: Pull complete
# 30e069d8e198: Pull complete
# a82e4e12442c: Pull complete
# 1bb969deda78: Pull complete
# 85856583f10d: Pull complete
# 103fa978967f: Pull complete
# Digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1@sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#  ---> faddb90bd04e
# Step 2/18 : USER root
#  ---> Running in 3058aa8afa46
# Removing intermediate container 3058aa8afa46
#  ---> d892707d9b28
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 7d32dd6c08d2
# Removing intermediate container 7d32dd6c08d2
#  ---> 0f7cf6dfb049
# Step 4/18 : WORKDIR /
#  ---> Running in 9bf2dfdacf3d
# Removing intermediate container 9bf2dfdacf3d
#  ---> dbc5d210d902
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 207353d377de
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 14029669b208
# Removing intermediate container 14029669b208
#  ---> 666addce459c
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> c0c56cb1693a
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 754bd99e878a
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libgcc-ng-9.1.0      | 5.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 5.1 MB    | ######6    |  66%
# libgcc-ng-9.1.0      | 5.1 MB    | ########## | 100%
#
# ca-certificates-2021 | 114 KB    |            |   0%
# ca-certificates-2021 | 114 KB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ######3    |  63%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# sqlite-3.35.4        | 981 KB    |            |   0%
# sqlite-3.35.4        | 981 KB    | ########## | 100%
#
# python-3.7.10        | 45.2 MB   |            |   0%
# python-3.7.10        | 45.2 MB   | #4         |  14%
# python-3.7.10        | 45.2 MB   | ###2       |  32%
# python-3.7.10        | 45.2 MB   | #####2     |  53%
# python-3.7.10        | 45.2 MB   | #######2   |  73%
# python-3.7.10        | 45.2 MB   | ########7  |  87%
# python-3.7.10        | 45.2 MB   | ########## | 100%
#
# ld_impl_linux-64-2.3 | 568 KB    |            |   0%
# ld_impl_linux-64-2.3 | 568 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# certifi-2020.12.5    | 141 KB    |            |   0%
# certifi-2020.12.5    | 141 KB    | ########## | 100%
#
# setuptools-52.0.0    | 710 KB    |            |   0%
# setuptools-52.0.0    | 710 KB    | ########## | 100%
#
# pip-21.0.1           | 1.8 MB    |            |   0%
# pip-21.0.1           | 1.8 MB    | ########## | 100%
#
# readline-8.1         | 362 KB    |            |   0%
# readline-8.1         | 362 KB    | ########## | 100%
#
# libffi-3.3           | 50 KB     |            |   0%
# libffi-3.3           | 50 KB     | ########## | 100%
#
# ncurses-6.2          | 817 KB    |            |   0%
# ncurses-6.2          | 817 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 3.1 MB    | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# openssl-1.1.1k       | 2.5 MB    |            |   0%
# openssl-1.1.1k       | 2.5 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.jfaxl3ww.requirements.txt']
# Pip subprocess output:
# Collecting mlflow
#   Downloading mlflow-1.17.0-py3-none-any.whl (14.2 MB)
# Collecting matplotlib
#   Downloading matplotlib-3.4.2-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
# Collecting seaborn
#   Downloading seaborn-0.11.1-py3-none-any.whl (285 kB)
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting azureml-mlflow
#   Downloading azureml_mlflow-1.28.0-py3-none-any.whl (41 kB)
# Collecting azureml-dataprep
#   Downloading azureml_dataprep-2.16.0-py3-none-any.whl (39.4 MB)
# Collecting anomatools
#   Downloading anomatools-2.3.0-py3-none-any.whl (25 kB)
# Collecting dtaidistance
#   Downloading dtaidistance-2.2.5.tar.gz (932 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting numpy>=1.13.3
#   Downloading numpy-1.20.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.3 MB)
# Collecting scikit-learn>=0.21.3
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
# Requirement already satisfied: setuptools>=41.6.0 in /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c/lib/python3.7/site-packages (from anomatools->-r /azureml-environment-setup/condaenv.jfaxl3ww.requirements.txt (line 7)) (52.0.0.post20210125)
# Collecting scipy>=0.19.1
#   Downloading scipy-1.6.3-cp37-cp37m-manylinux1_x86_64.whl (27.4 MB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Collecting joblib>=0.11
#   Downloading joblib-1.0.1-py3-none-any.whl (303 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.15.0a,>=1.14.0dev0
#   Downloading azureml_dataprep_rslex-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-native<35.0.0,>=34.0.0
#   Downloading azureml_dataprep_native-34.0.0-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.11.0-py2.py3-none-any.whl (63 kB)
# Collecting six>=1.6
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.13.0-py2.py3-none-any.whl (133 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting requests>=2.18.4
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp37-cp37m-manylinux1_x86_64.whl (402 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c/lib/python3.7/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.0.0->azure-identity<1.5.0,>=1.2.0->azureml-dataprep->-r /azureml-environment-setup/condaenv.jfaxl3ww.requirements.txt (line 6)) (2020.12.5)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting azureml-core~=1.28.0
#   Downloading azureml_core-1.28.0-py3-none-any.whl (2.2 MB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting protobuf>=3.6.0
#   Downloading protobuf-3.16.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting gitpython>=2.1.0
#   Downloading GitPython-3.1.14-py3-none-any.whl (159 kB)
# Collecting sqlparse>=0.3.1
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting entrypoints
#   Downloading entrypoints-0.3-py2.py3-none-any.whl (11 kB)
# Collecting Flask
#   Downloading Flask-2.0.0-py3-none-any.whl (93 kB)
# Collecting click>=7.0
#   Downloading click-8.0.0-py3-none-any.whl (96 kB)
# Collecting gunicorn
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting pyyaml
#   Downloading PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.15-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
# Collecting alembic<=1.4.1
#   Downloading alembic-1.4.1.tar.gz (1.1 MB)
# Collecting docker>=4.0.0
#   Downloading docker-5.0.0-py2.py3-none-any.whl (146 kB)
# Collecting prometheus-flask-exporter
#   Downloading prometheus_flask_exporter-0.18.2.tar.gz (22 kB)
# Collecting databricks-cli>=0.8.7
#   Downloading databricks-cli-0.14.3.tar.gz (54 kB)
# Collecting querystring-parser
#   Downloading querystring_parser-1.2.4-py2.py3-none-any.whl (7.9 kB)
# Collecting pandas
#   Downloading pandas-1.2.4-cp37-cp37m-manylinux1_x86_64.whl (9.9 MB)
# Collecting Mako
#   Downloading Mako-1.1.4-py2.py3-none-any.whl (75 kB)
# Collecting python-editor>=0.3
#   Downloading python_editor-1.0.4-py3-none-any.whl (4.9 kB)
# Collecting python-dateutil
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting ruamel.yaml<1.0.0,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting docker>=4.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting tabulate>=0.7.7
#   Downloading tabulate-0.8.9-py3-none-any.whl (25 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.59.0-py2.py3-none-any.whl (67 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.7-py3-none-any.whl (63 kB)
# Collecting smmap<5,>=3.0.1
#   Downloading smmap-4.0.0-py2.py3-none-any.whl (24 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.0.1-py3-none-any.whl (16 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp37-cp37m-manylinux1_x86_64.whl (547 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-1.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (160 kB)
# Collecting cython>=0.29.6
#   Using cached Cython-0.29.23-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.1-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
# Collecting pyparsing>=2.2.1
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting cycler>=0.10
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-8.2.0-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting Werkzeug>=2.0
#   Downloading Werkzeug-2.0.0-py3-none-any.whl (288 kB)
# Collecting Jinja2>=3.0
#   Downloading Jinja2-3.0.0-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=2.0
#   Downloading itsdangerous-2.0.0-py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0.0rc2
#   Downloading MarkupSafe-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (31 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting prometheus_client
#   Downloading prometheus_client-0.10.1-py2.py3-none-any.whl (55 kB)
# Building wheels for collected packages: alembic, databricks-cli, dtaidistance, sklearn, prometheus-flask-exporter
#   Building wheel for alembic (setup.py): started
#   Building wheel for alembic (setup.py): finished with status 'done'
#   Created wheel for alembic: filename=alembic-1.4.1-py2.py3-none-any.whl size=158155 sha256=58ee12dfc0d122d501fda532a914d0342e3bda06badf45f99b45a64375e9fa9c
#   Stored in directory: /root/.cache/pip/wheels/be/5d/0a/9e13f53f4f5dfb67cd8d245bb7cdffe12f135846f491a283e3
#   Building wheel for databricks-cli (setup.py): started
#   Building wheel for databricks-cli (setup.py): finished with status 'done'
#   Created wheel for databricks-cli: filename=databricks_cli-0.14.3-py3-none-any.whl size=100555 sha256=bd220372fe3a6ed3d8c23a956f1d9b102bb5362ff95019195c8eeae62d672257
#   Stored in directory: /root/.cache/pip/wheels/3b/60/14/6930445b08959fbdf4e3029bac7e1f2cccb2e94df8afa00b29
#   Building wheel for dtaidistance (PEP 517): started
#   Building wheel for dtaidistance (PEP 517): finished with status 'done'
#   Created wheel for dtaidistance: filename=dtaidistance-2.2.5-cp37-cp37m-linux_x86_64.whl size=1570225 sha256=aa3bf77b2da5270f44d1c8496125a3772e66070f6b348c9ca779735299f7a7ee
#   Stored in directory: /root/.cache/pip/wheels/43/2a/9c/917e2e688946efce68fc12d1f0cfe8cadabdf0791e67bf36d8
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=fa04678f630b60ee0734ef8dc1089e2ecb73c41886571340a5bf02f03ecccc52
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
#   Building wheel for prometheus-flask-exporter (setup.py): started
#   Building wheel for prometheus-flask-exporter (setup.py): finished with status 'done'
#   Created wheel for prometheus-flask-exporter: filename=prometheus_flask_exporter-0.18.2-py3-none-any.whl size=17399 sha256=01349ae92b251e9e20609c594bbf731d7412493d0d80714cf214486dd0cb9aa3
#   Stored in directory: /root/.cache/pip/wheels/6a/1e/1c/c765920cb92b2f0343d2dd8b481a407cee2823f9b4bbd2e52a
# Successfully built alembic databricks-cli dtaidistance sklearn prometheus-flask-exporter
# Installing collected packages: urllib3, pycparser, idna, chardet, six, requests, oauthlib, cffi, zipp, typing-extensions, requests-oauthlib, python-dateutil, PyJWT, MarkupSafe, isodate, cryptography, Werkzeug, smmap, msrest, Jinja2, itsdangerous, importlib-metadata, greenlet, click, adal, websocket-client, tabulate, sqlalchemy, ruamel.yaml.clib, pytz, python-editor, pyopenssl, pyasn1, prometheus-client, portalocker, numpy, msrestazure, msal, Mako, jeepney, gitdb, Flask, backports.weakref, azure-common, threadpoolctl, sqlparse, SecretStorage, scipy, ruamel.yaml, querystring-parser, pyyaml, pyparsing, protobuf, prometheus-flask-exporter, pillow, pathspec, pandas, ndg-httpsclient, msal-extensions, kiwisolver, jsonpickle, joblib, jmespath, gunicorn, gitpython, entrypoints, docker, distro, databricks-cli, cycler, contextlib2, cloudpickle, backports.tempfile, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, azure-core, alembic, scikit-learn, mlflow, matplotlib, dotnetcore2, cython, azureml-dataprep-rslex, azureml-dataprep-native, azureml-core, azure-identity, sklearn, seaborn, dtaidistance, azureml-mlflow, azureml-dataprep, anomatools
# Successfully installed Flask-2.0.0 Jinja2-3.0.0 Mako-1.1.4 MarkupSafe-2.0.0 PyJWT-2.1.0 SecretStorage-3.3.1 Werkzeug-2.0.0 adal-1.2.7 alembic-1.4.1 anomatools-2.3.0 azure-common-1.1.27 azure-core-1.13.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.28.0 azureml-dataprep-2.16.0 azureml-dataprep-native-34.0.0 azureml-dataprep-rslex-1.14.0 azureml-mlflow-1.28.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.0 cloudpickle-1.6.0 contextlib2-0.6.0.post1 cryptography-3.4.7 cycler-0.10.0 cython-0.29.23 databricks-cli-0.14.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 dtaidistance-2.2.5 entrypoints-0.3 gitdb-4.0.7 gitpython-3.1.14 greenlet-1.1.0 gunicorn-20.1.0 idna-2.10 importlib-metadata-4.0.1 isodate-0.6.0 itsdangerous-2.0.0 jeepney-0.6.0 jmespath-0.10.0 joblib-1.0.1 jsonpickle-2.0.0 kiwisolver-1.3.1 matplotlib-3.4.2 mlflow-1.17.0 msal-1.11.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 numpy-1.20.3 oauthlib-3.1.0 pandas-1.2.4 pathspec-0.8.1 pillow-8.2.0 portalocker-1.7.1 prometheus-client-0.10.1 prometheus-flask-exporter-0.18.2 protobuf-3.16.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 python-dateutil-2.8.1 python-editor-1.0.4 pytz-2021.1 pyyaml-5.4.1 querystring-parser-1.2.4 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 scikit-learn-0.24.2 scipy-1.6.3 seaborn-0.11.1 six-1.16.0 sklearn-0.0 smmap-4.0.0 sqlalchemy-1.4.15 sqlparse-0.4.1 tabulate-0.8.9 threadpoolctl-2.1.0 typing-extensions-3.10.0.0 urllib3-1.26.4 websocket-client-0.59.0 zipp-3.4.1
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 754bd99e878a
#  ---> a4b4ffc267b4
# Step 9/18 : ENV PATH /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c/bin:$PATH
#  ---> Running in ca6c8cbcaa63
# Removing intermediate container ca6c8cbcaa63
#  ---> 9876ca1ff5da
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> d1e3b7ae0bde
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 0cd1404f0ede
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c
#  ---> Running in d0170420d3c0
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container d0170420d3c0
#  ---> 382ffdef1cf8
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c
#  ---> Running in 01561f2e2e4e
# Removing intermediate container 01561f2e2e4e
#  ---> 311301101da7
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_e56cd4b3a5990d1de1219de41cec8c6c/lib:$LD_LIBRARY_PATH
#  ---> Running in 7f5e652f3ad0
# Removing intermediate container 7f5e652f3ad0
#  ---> dcf6200f020a
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> eb4bc4102b18
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 3c23c3544f32
# Removing intermediate container 3c23c3544f32
#  ---> e6d3e57bbe2f
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in c28fccc956c3
# Removing intermediate container c28fccc956c3
#  ---> 93b6afa9f994
# Step 18/18 : CMD ["bash"]
#  ---> Running in a88e5bc55b83
# Removing intermediate container a88e5bc55b83
#  ---> b25d3b8ec3f6
# Successfully built b25d3b8ec3f6
# Successfully tagged 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:latest
# Successfully tagged 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:1
# 2021/05/12 20:41:37 Successfully executed container: acb_step_0
# 2021/05/12 20:41:37 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/12 20:41:37 Pushing image: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:1, attempt 1
# The push refers to repository [27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28]
# a03bc4d31e7d: Preparing
# 36fa315a8e1e: Preparing
# e91d89d5cf6e: Preparing
# 521245c1e6e6: Preparing
# 6dc7ec6d490a: Preparing
# 64b206ed4d93: Preparing
# 670f8a2d3f82: Preparing
# 6955cd0eaa19: Preparing
# 000506e7cd4c: Preparing
# 11a33be78ee4: Preparing
# 7e92ccffb921: Preparing
# 7bd1885661f8: Preparing
# cfbdd4b09eb1: Preparing
# 1279e1c526b8: Preparing
# eb152233bfcc: Preparing
# 1bd2431681e9: Preparing
# f4424f38afe7: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 64b206ed4d93: Waiting
# 670f8a2d3f82: Waiting
# 6955cd0eaa19: Waiting
# 000506e7cd4c: Waiting
# 1bd2431681e9: Waiting
# 11a33be78ee4: Waiting
# 7e92ccffb921: Waiting
# f4424f38afe7: Waiting
# 5276d2b930fc: Waiting
# 7bd1885661f8: Waiting
# cfbdd4b09eb1: Waiting
# 1279e1c526b8: Waiting
# eb152233bfcc: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# e6feec0db89a: Waiting
# 521245c1e6e6: Pushed
# a03bc4d31e7d: Pushed
# e91d89d5cf6e: Pushed
# 36fa315a8e1e: Pushed
# 64b206ed4d93: Pushed
# 6955cd0eaa19: Pushed
# 670f8a2d3f82: Pushed
# 000506e7cd4c: Pushed
# 11a33be78ee4: Pushed
# 7e92ccffb921: Pushed
# 7bd1885661f8: Pushed
# 1bd2431681e9: Pushed
# cfbdd4b09eb1: Pushed
# eb152233bfcc: Pushed
# e6feec0db89a: Pushed
# 5276d2b930fc: Pushed
# 1279e1c526b8: Pushed
# 697949baa658: Pushed
# f4424f38afe7: Pushed
# 935c56d8b3f9: Pushed
# 6dc7ec6d490a: Pushed
# 1: digest: sha256:e06920bded060ea61d2a99cd2b9fc861c8804b8f86619f29945d63d4e94112b9 size: 4721
# 2021/05/12 20:43:13 Successfully pushed image: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:1
# 2021/05/12 20:43:13 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/05/12 20:43:13 Pushing image: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:latest, attempt 1
# The push refers to repository [27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28]
# a03bc4d31e7d: Preparing
# 36fa315a8e1e: Preparing
# e91d89d5cf6e: Preparing
# 521245c1e6e6: Preparing
# 6dc7ec6d490a: Preparing
# 64b206ed4d93: Preparing
# 670f8a2d3f82: Preparing
# 6955cd0eaa19: Preparing
# 000506e7cd4c: Preparing
# 11a33be78ee4: Preparing
# 7e92ccffb921: Preparing
# 7bd1885661f8: Preparing
# cfbdd4b09eb1: Preparing
# 1279e1c526b8: Preparing
# eb152233bfcc: Preparing
# 1bd2431681e9: Preparing
# f4424f38afe7: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# 64b206ed4d93: Waiting
# 670f8a2d3f82: Waiting
# 6955cd0eaa19: Waiting
# 000506e7cd4c: Waiting
# 11a33be78ee4: Waiting
# 7e92ccffb921: Waiting
# 7bd1885661f8: Waiting
# cfbdd4b09eb1: Waiting
# 1279e1c526b8: Waiting
# eb152233bfcc: Waiting
# 1bd2431681e9: Waiting
# f4424f38afe7: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# 36fa315a8e1e: Layer already exists
# 521245c1e6e6: Layer already exists
# 6dc7ec6d490a: Layer already exists
# e91d89d5cf6e: Layer already exists
# a03bc4d31e7d: Layer already exists
# 670f8a2d3f82: Layer already exists
# 64b206ed4d93: Layer already exists
# 11a33be78ee4: Layer already exists
# 6955cd0eaa19: Layer already exists
# 000506e7cd4c: Layer already exists
# 7e92ccffb921: Layer already exists
# 7bd1885661f8: Layer already exists
# cfbdd4b09eb1: Layer already exists
# 1279e1c526b8: Layer already exists
# eb152233bfcc: Layer already exists
# 1bd2431681e9: Layer already exists
# 5276d2b930fc: Layer already exists
# 697949baa658: Layer already exists
# e6feec0db89a: Layer already exists
# 935c56d8b3f9: Layer already exists
# f4424f38afe7: Layer already exists
# latest: digest: sha256:e06920bded060ea61d2a99cd2b9fc861c8804b8f86619f29945d63d4e94112b9 size: 4721
# 2021/05/12 20:43:14 Successfully pushed image: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io/azureml/azureml_2cfff7c70113e88656550f2067b3af28:latest
# 2021/05/12 20:43:14 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 196.064474)
# 2021/05/12 20:43:14 Populating digests for step ID: acb_step_0...
# 2021/05/12 20:43:19 Successfully populated digests for step ID: acb_step_0
# 2021/05/12 20:43:19 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 95.400620)
# 2021/05/12 20:43:19 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 1.418457)
# 2021/05/12 20:43:19 The following dependencies were found:
# 2021/05/12 20:43:19
# - image:
#     registry: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io
#     repository: azureml/azureml_2cfff7c70113e88656550f2067b3af28
#     tag: latest
#     digest: sha256:e06920bded060ea61d2a99cd2b9fc861c8804b8f86619f29945d63d4e94112b9
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210129.v1
#     digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#   git: {}
# - image:
#     registry: 27ebdbdbb34a4186a9c6cf92029c3be2.azurecr.io
#     repository: azureml/azureml_2cfff7c70113e88656550f2067b3af28
#     tag: "1"
#     digest: sha256:e06920bded060ea61d2a99cd2b9fc861c8804b8f86619f29945d63d4e94112b9
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210129.v1
#     digest: sha256:19fe6a6202757242643beace8d3d690519f431deb21adc072989185425a22133
#   git: {}
#
#
# Run ID: ca8 was successful after 5m5s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt
# ========================================================================================================================
#
# 2021-05-12T20:47:34Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/mounts/workspaceblobstore
# 2021-05-12T20:47:35Z Starting output-watcher...
# 2021-05-12T20:47:35Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-05-12T20:47:35Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-05-12T20:47:35Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_4539de3ccb169db6707c8cade7afe14c
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# 574f361512d6: Pulling fs layer
# db4d1e2d7079: Pulling fs layer
# e544ee0f522d: Pulling fs layer
# c655136086be: Pulling fs layer
# 2ec37f44090c: Pulling fs layer
# 5fba3bd4a2c4: Pulling fs layer
# 7e0ea9d0a1ab: Pulling fs layer
# da005f826951: Pulling fs layer
# ac4e1c91b241: Pulling fs layer
# efb648489c68: Pulling fs layer
# e5e2bb35fef1: Pulling fs layer
# 41f64f9d12ca: Pulling fs layer
# 404e390f8ac9: Pulling fs layer
# 00d1c09f699a: Pulling fs layer
# 4c6ec688ebe3: Waiting
# 574f361512d6: Waiting
# db4d1e2d7079: Waiting
# e544ee0f522d: Waiting
# c655136086be: Waiting
# 2ec37f44090c: Waiting
# 5fba3bd4a2c4: Waiting
# 7e0ea9d0a1ab: Waiting
# da005f826951: Waiting
# ac4e1c91b241: Waiting
# efb648489c68: Waiting
# e5e2bb35fef1: Waiting
# 41f64f9d12ca: Waiting
# 404e390f8ac9: Waiting
# 00d1c09f699a: Waiting
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 5dfa26c6b9c9: Verifying Checksum
# 5dfa26c6b9c9: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# db4d1e2d7079: Verifying Checksum
# db4d1e2d7079: Download complete
# 574f361512d6: Verifying Checksum
# 574f361512d6: Download complete
# e544ee0f522d: Verifying Checksum
# e544ee0f522d: Download complete
# 5fba3bd4a2c4: Verifying Checksum
# 5fba3bd4a2c4: Download complete
# 2ec37f44090c: Verifying Checksum
# 2ec37f44090c: Download complete
# 7e0ea9d0a1ab: Verifying Checksum
# 7e0ea9d0a1ab: Download complete
# da005f826951: Verifying Checksum
# da005f826951: Download complete
# ac4e1c91b241: Verifying Checksum
# ac4e1c91b241: Download complete
# c655136086be: Verifying Checksum
# c655136086be: Download complete
# e5e2bb35fef1: Verifying Checksum
# e5e2bb35fef1: Download complete
# 41f64f9d12ca: Verifying Checksum
# 41f64f9d12ca: Download complete
# 404e390f8ac9: Verifying Checksum
# 404e390f8ac9: Download complete
# 00d1c09f699a: Verifying Checksum
# 00d1c09f699a: Download complete
# efb648489c68: Verifying Checksum
# efb648489c68: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# 574f361512d6: Pull complete
# db4d1e2d7079: Pull complete
# e544ee0f522d: Pull complete
# c655136086be: Pull complete
# 2ec37f44090c: Pull complete
# 5fba3bd4a2c4: Pull complete
# 7e0ea9d0a1ab: Pull complete
# da005f826951: Pull complete
# ac4e1c91b241: Pull complete
# efb648489c68: Pull complete
# e5e2bb35fef1: Pull complete
# 41f64f9d12ca: Pull complete
# 404e390f8ac9: Pull complete
# 00d1c09f699a: Pull complete
# Digest: sha256:a42e3315fb9cd2730a052be10a9492e8f265703745b1e8029604c5c178f93426
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# viennaglobal.azurecr.io/azureml/azureml_4539de3ccb169db6707c8cade7afe14c:latest
# 2021-05-12T20:49:26Z Check if container knnosample_1620851888_69798bc0_DataSidecar already exist exited with 0,
#
#
# Streaming azureml-logs/65_job_prep-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt
# ===============================================================================================================
#
# [2021-05-12T20:49:43.753614] Entering job preparation.
# [2021-05-12T20:49:44.572534] Starting job preparation.
# [2021-05-12T20:49:44.572584] Extracting the control code.
# [2021-05-12T20:49:44.608602] fetching and extracting the control code on master node.
# [2021-05-12T20:49:44.608647] Starting extract_project.
# [2021-05-12T20:49:44.608682] Starting to extract zip file.
# [2021-05-12T20:49:45.214438] Finished extracting zip file.
# [2021-05-12T20:49:45.392440] Using urllib.request Python 3.0 or later
# [2021-05-12T20:49:45.392524] Start fetching snapshots.
# [2021-05-12T20:49:45.392573] Start fetching snapshot.
# [2021-05-12T20:49:45.392591] Retrieving project from snapshot: 44e342a7-7c1c-4ded-b03b-d86f2119be6d
# Starting the daemon thread to refresh tokens in background for process with pid = 55
# [2021-05-12T20:49:45.932548] Finished fetching snapshot.
# [2021-05-12T20:49:45.932584] Finished fetching snapshots.
# [2021-05-12T20:49:45.932597] Finished extract_project.
# [2021-05-12T20:49:45.946916] Finished fetching and extracting the control code.
# [2021-05-12T20:49:45.953786] Start run_history_prep.
# [2021-05-12T20:49:46.015458] Job preparation is complete.
# [2021-05-12T20:49:46.015721] Entering Data Context Managers in Sidecar
# [2021-05-12T20:49:46.016664] Running Sidecar prep cmd...
# [2021-05-12T20:49:46.447831] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/mounts/workspaceblobstore/azureml/kNNOSample_1620851888_69798bc0
# [2021-05-12T20:49:46.448790] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.26.0 azureml-dataprep==2.14.2. Session id: 1b665fd9-ec2a-4ec4-a87c-e283c32862f1. Run id: kNNOSample_1620851888_69798bc0.
# Processing 'input__fcb09a95'.
# Processing dataset FileDataset
# {
#   "source": [
#     "http://kdd.ics.uci.edu/databases/kddcup99/kddcup.data_10_percent.gz"
#   ],
#   "definition": [
#     "GetFiles"
#   ],
#   "registration": {
#     "id": "d4023713-1cdf-4f6e-8670-7fd800a85d2c",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='AnomalyDetection', subscription_id='6560575d-fa06-4e7d-95fb-f962e74efd7a', resource_group='UW_AnomalyDetection')"
#   }
# }
# Mounting input__fcb09a95 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/wd/tmpo1e_bnhh.
# Mounted input__fcb09a95 to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/wd/tmpo1e_bnhh as single file.
# Exit __enter__ of DatasetContextManager
# Set Dataset input__fcb09a95's target path to /mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/wd/tmpo1e_bnhh/kddcup.data_10_percent.gz
# [2021-05-12T20:49:57.335053] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-05-12T20:49:57.924533] Ran Sidecar prep cmd.
# [2021-05-12T20:49:57.924615] Running Context Managers in Sidecar complete.
#
# Streaming azureml-logs/75_job_post-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt
# ===============================================================================================================
#
# [2021-05-12T20:52:20.438571] Entering job release
# [2021-05-12T20:52:21.470602] Starting job release
# [2021-05-12T20:52:21.471496] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 285
# [2021-05-12T20:52:21.471912] job release stage : upload_datastore starting...
# [2021-05-12T20:52:21.483563] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-05-12T20:52:21.483995] job release stage : copy_batchai_cached_logs starting...[2021-05-12T20:52:21.484191] job release stage : execute_job_release starting...
#
# [2021-05-12T20:52:21.484390] job release stage : copy_batchai_cached_logs completed...
# [2021-05-12T20:52:21.545546] Entering context manager injector.
# [2021-05-12T20:52:21.552920] job release stage : upload_datastore completed...
# [2021-05-12T20:52:21.595422] job release stage : send_run_telemetry starting...
# [2021-05-12T20:52:21.635205] job release stage : execute_job_release completed...
# [2021-05-12T20:52:21.778971] get vm size and vm region successfully.
# [2021-05-12T20:52:21.810025] get compute meta data successfully.
# [2021-05-12T20:52:22.227845] post artifact meta request successfully.
# [2021-05-12T20:52:22.282049] upload compute record artifact successfully.
# [2021-05-12T20:52:22.282183] job release stage : send_run_telemetry completed...
# [2021-05-12T20:52:22.282884] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-05-12T20:52:22.282991] Running Sidecar release cmd...
# [2021-05-12T20:52:22.296039] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/mounts/workspaceblobstore/azureml/kNNOSample_1620851888_69798bc0
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/wd/tmpo1e_bnhh.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/anomalydetection/azureml/knnosample_1620851888_69798bc0/wd/tmpo1e_bnhh.
# Exit __exit__ of DatasetContextManager
# [2021-05-12T20:52:22.377417] Removing absolute paths from host...
# [2021-05-12T20:52:22.385539] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-05-12T20:52:23.037825] Ran Sidecar release cmd.
# [2021-05-12T20:52:23.037953] Job release is complete
#
# Execution Summary
# =================
# RunId: kNNOSample_1620851888_69798bc0
# Web View: https://ml.azure.com/experiments/kNNOSample/runs/kNNOSample_1620851888_69798bc0?wsid=/subscriptions/6560575d-fa06-4e7d-95fb-f962e74efd7a/resourcegroups/UW_AnomalyDetection/workspaces/AnomalyDetection
# {'runId': 'kNNOSample_1620851888_69798bc0',
#  'target': 'WorkspaceCompute',
#  'status': 'Completed',
#  'startTimeUtc': '2021-05-12T20:47:32.541222Z',
#  'endTimeUtc': '2021-05-12T20:52:31.170507Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': '66d56410-3932-41b9-9dbf-f61faf333459',
#   'azureml.git.repository_uri': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'mlflow.source.git.repoURL': 'https://github.com/danielgchen/MS_AZML_Anomaly_Detection.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': 'de8c0bfe9ef5d093bbf7763db632dca36cee9440',
#   'mlflow.source.git.commit': 'de8c0bfe9ef5d093bbf7763db632dca36cee9440',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input__fcb09a95', 'mechanism': 'Mount'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'azure_knno.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--data-path', 'DatasetConsumptionConfig:input__fcb09a95'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'WorkspaceCompute',
#   'dataReferences': {},
#   'data': {'input__fcb09a95': {'dataLocation': {'dataset': {'id': 'd4023713-1cdf-4f6e-8670-7fd800a85d2c',
#       'name': None,
#       'version': None},
#      'dataPath': None,
#      'uri': None},
#     'mechanism': 'Mount',
#     'environmentVariableName': 'input__fcb09a95',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'SampleEnv',
#    'version': 'Autosave_2021-05-12T20:38:09Z_6d41440e',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['defaults', 'anaconda', 'conda-forge'],
#      'dependencies': ['python=3.7',
#       'pip',
#       {'pip': ['mlflow',
#         'matplotlib',
#         'seaborn',
#         'sklearn',
#         'azureml-mlflow',
#         'azureml-dataprep',
#         'anomatools',
#         'dtaidistance']}],
#      'name': 'azureml_e56cd4b3a5990d1de1219de41cec8c6c'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210129.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'dockerContext': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None,
#    'virtualClusterArmId': None,
#    'tensorboardLogDirectory': None,
#    'sshPublicKey': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': 'nccl', 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []},
#   'environmentVariables': {},
#   'applicationEndpoints': {}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=jAsK3qI3jKluG0sdp0QuS8eN5EusUPksun22eMXlCTU%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/55_azureml-execution-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt?sv=2019-02-02&sr=b&sig=MMNrbwBywF947KxjQ0jmkng5hLfhd3KVJCz3Q89Gpbk%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/65_job_prep-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt?sv=2019-02-02&sr=b&sig=k9Vje%2Bp6HdGNeIpR6HkFYsBh021Qk6D4ZrueUXpbYOY%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=1hRWQMQKIYw6BJvpCSWurTZXAXO3AQzO8oNMopzDjGQ%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/75_job_post-tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d.txt?sv=2019-02-02&sr=b&sig=hLJulWQ2R17Sth5yPN%2Fitto2wRjYi4K7GY9iu87Vw40%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/process_info.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=WMYqKdXG0k122FvHGGwnY9wJnNVlIb5g6kQbdSJ%2BITg%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'azureml-logs/process_status.json': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=7YkF43mOlU4VVfv5AjkiuKNbFhtbm6oPhkrdiOIG6AM%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/80_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/80_azureml.log?sv=2019-02-02&sr=b&sig=5%2Bh27o%2F%2BrE2w0T5xkDGZnMhiFI1bUD7Dxzs%2FG82wOv4%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=TTBhNQmcdidkfTwUzyYwFpu93RPG3LszAtIRqZRlIoQ%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=JxVzBYZiuaLYaVxqHoCDU5HAJ7gLrr2A9Sf709NJ2hk%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=8UAFcMLA%2FIi%2BmwL7tl1HuKXU4WFXIRhkF18wmzKhH1U%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=CZ1X8BQGz37bZpvQSlaXrmRK%2BUZSjRjGkiaCKKVITRo%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/all.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/all.log?sv=2019-02-02&sr=b&sig=nblk4GR86yJYDgPkBgBArjIdx4c5BW1zbsxOqfz9Alo%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/task.enter_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/task.enter_contexts.log?sv=2019-02-02&sr=b&sig=0wH4zgENo9UjHkBDSPGsIJtxKAJiicrwykmrFl0VwLQ%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r',
#   'logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/task.exit_contexts.log': 'https://anomalydetecti4902467972.blob.core.windows.net/azureml/ExperimentRun/dcid.kNNOSample_1620851888_69798bc0/logs/azureml/sidecar/tvmps_63558cb581aa72ae4ce5cdb47919b108eca3a3aca3d7b8946bced30347501d87_d/task.exit_contexts.log?sv=2019-02-02&sr=b&sig=dcoiNWCAvq%2BZpuoOzFyLWtxzNs98uWiuJf3GsgOZGLI%3D&st=2021-05-12T20%3A42%3A30Z&se=2021-05-13T04%3A52%3A30Z&sp=r'},
#  'submittedBy': 'Daniel Chen'}
